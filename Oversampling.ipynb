# %%
## install pypi release
# !pip install smogn

## install developer version
#!pip install git+https://github.com/nickkunz/smogn.git

# %%
## load dependencies
import smogn
import pandas

# %%
df = pandas.read_excel(r"C:\Users\Chris\OneDrive\Escritorio\KU Leuven\Master Thesis\normalized_dataset_sqrt_TrainingSet.xlsx")
df.head()
# Out:
#    Event_Code  Type_Code  Deceased  Injured       Sick  Homeless  Displaced  \
# 0  118.785521          1       0.0      0.0  15.491933       0.0   0.000000
# 1  110.453610          1       0.0      0.0   0.000000       0.0   0.000000
# 2  118.785521          1       0.0      0.0   0.000000       0.0   0.000000
# 3  118.785521          1       0.0      0.0   0.000000       0.0   0.000000
# 4  110.000000          1       0.0      0.0   0.000000       0.0   7.071068
#
#    MissingPeople       Other       Total  ...  \
# 0            0.0    0.000000   15.491933  ...
# 1            0.0   50.990195   50.990195  ...
# 2            0.0    0.000000    0.000000  ...
# 3            0.0  133.240384  133.240384  ...
# 4            0.0    0.000000    7.071068  ...
#
#    Two_Months_Prior_Standard_Deviation_Bulbo_Seco_Daily_Temperature  \
# 0                                           5.954220
# 1                                           6.179799
# ...

# %%
## specify phi relevance values

rg_mtrx = [

    [1,  1, 0],  ## over-sample ("minority")
[1.41421356237309, 1, 0], ## over-sample ("minority")
[2, 1, 0],## over-sample ("minority")
[1.73205080756888, 1, 0],## over-sample ("minority")
[2.23606797749979, 1, 0],## over-sample ("minority")
[2.82842712474619, 1, 0],## over-sample ("minority")
[3, 1, 0],## over-sample ("minority")
[3.46410161513775, 1, 0],## over-sample ("minority")
[2.44948974278318, 1, 0],## over-sample ("minority")
[4.47213595499958, 1, 0],## over-sample ("minority")
[3.16227766016838, 1, 0],## over-sample ("minority")
[4, 1, 0],## over-sample ("minority")
[7.74596669241483, 1, 0],## over-sample ("minority")
[3.3166247903554, 1, 0],## over-sample ("minority")
[6.32455532033676, 1, 0],## over-sample ("minority")
[2.64575131106459, 1, 0],## over-sample ("minority")
[3.87298334620742, 1, 0],## over-sample ("minority")
[3.74165738677394, 1, 0],## over-sample ("minority")
[8.94427190999916, 1, 0],## over-sample ("minority")
[3.60555127546399, 1, 0],## over-sample ("minority")
[4.12310562561766, 1, 0],## over-sample ("minority")
[12.2474487139159, 1, 0],## over-sample ("minority")
[5.29150262212918, 1, 0],## over-sample ("minority")
[5.09901951359279, 1, 0],## over-sample ("minority")
[6, 1, 0],## over-sample ("minority")
[5.65685424949238, 1, 0],## over-sample ("minority")
[15.8113883008419, 1, 0],## over-sample ("minority")
[5.47722557505166, 1, 0],## over-sample ("minority")
[9.48683298050514, 1, 0],## over-sample ("minority")
[5.74456264653803, 1, 0],## over-sample ("minority")
[13.4164078649987, 1, 0],## over-sample ("minority")
[4.69041575982343, 1, 0],## over-sample ("minority")
[4.58257569495584, 1, 0],## over-sample ("minority")
[6.16441400296898, 1, 0],## over-sample ("minority")
[9.64365076099295, 1, 0],## over-sample ("minority")
[4.89897948556636, 1, 0],## over-sample ("minority")
[12.6491106406735, 1, 0],## over-sample ("minority")
[19.94993734326, 1, 0],## over-sample ("minority")
[14.1421356237309, 1, 0],## over-sample ("minority")
[4.24264068711928, 1, 0],## over-sample ("minority")
[5.19615242270663, 1, 0],## over-sample ("minority")
[17.3205080756888, 1, 0],## over-sample ("minority")
[6.40312423743285, 1, 0],## over-sample ("minority")
[10, 1, 0],## over-sample ("minority")
[7.07106781186548, 1, 0],## over-sample ("minority")
[7.41619848709566, 1, 0],## over-sample ("minority")
[10.9087121146357, 1, 0],## over-sample ("minority")
[5.8309518948453, 1, 0],## over-sample ("minority")
[13.5646599662505, 1, 0],## over-sample ("minority")
[20, 1, 0],## over-sample ("minority")
[5.3851648071345, 1, 0],## over-sample ("minority")
[23.4520787991171, 1, 0],## over-sample ("minority")
[10.1488915650922, 1, 0],## over-sample ("minority")
[16.1245154965971, 1, 0],## over-sample ("minority")
[11.180339887499, 1, 0],## over-sample ("minority")
[17.3781471969828, 1, 0],## over-sample ("minority")
[13.3416640641263, 1, 0],## over-sample ("minority")
[18.3303027798234, 1, 0],## over-sample ("minority")
[14.1774468787578, 1, 0],## over-sample ("minority")
[18.8679622641132, 1, 0],## over-sample ("minority")
[9.59166304662544, 1, 0],## over-sample ("minority")
[5.91607978309962, 1, 0],## over-sample ("minority")
[9.69535971483266, 1, 0],## over-sample ("minority")
[5, 1, 0],## over-sample ("minority")
[10.0995049383621, 1, 0],## over-sample ("minority")
[8.66025403784439, 1, 0],## over-sample ("minority")
[10.5356537528527, 1, 0],## over-sample ("minority")
[8.83176086632785, 1, 0],## over-sample ("minority")
[10.9544511501033, 1, 0],## over-sample ("minority")
[6.08276253029822, 1, 0],## over-sample ("minority")
[11.2694276695846, 1, 0],## over-sample ("minority")
[9.05538513813742, 1, 0],## over-sample ("minority")
[6.557438524302, 1, 0],## over-sample ("minority")
[9.1104335791443, 1, 0],## over-sample ("minority")
[6.85565460040104, 1, 0],## over-sample ("minority")
[9.16515138991168, 1, 0],## over-sample ("minority")
[6.92820323027551, 1, 0],## over-sample ("minority")
[9.21954445729289, 1, 0],## over-sample ("minority")
[15.4919333848297, 1, 0],## over-sample ("minority")
[9.4339811320566, 1, 0],## over-sample ("minority")
[7.21110255092798, 1, 0],## over-sample ("minority")
[4.35889894354067, 1, 0],## over-sample ("minority")
[28.2842712474619, 1, 0],## over-sample ("minority")
[17.7200451466693, 1, 0],## over-sample ("minority")
[31.6227766016838, 1, 0],## over-sample ("minority")
[18.6815416922694, 1, 0],## over-sample ("minority")
[38.7298334620742, 1, 0],## over-sample ("minority")
[19.672315572906, 1, 0],## over-sample ("minority")
[44.7213595499958, 1, 0],## over-sample ("minority")
[219.692967570653, 1, 0],## over-sample ("minority")
[20.6881608655772, 1, 0],## over-sample ("minority")
[7.81024967590665, 1, 0],## over-sample ("minority")
[26.9072480941474, 1, 0],## over-sample ("minority")
[7.87400787401181, 1, 0],## over-sample ("minority")
[31.559467676119, 1, 0],## over-sample ("minority")
[8, 1, 0],## over-sample ("minority")
[32.7108544675922, 1, 0],## over-sample ("minority")
[8.06225774829855, 1, 0],## over-sample ("minority")
[40, 1, 0],## over-sample ("minority")
[8.36660026534076, 1, 0],## over-sample ("minority")
[109.544511501033, 1, 0],## over-sample ("minority")
[8.42614977317636, 1, 0],## over-sample ("minority")
[8.54400374531753, 1, 0],## over-sample ("minority")
[8.60232526704263, 1, 0],    ## over-sample ("minority")
    [0, 0, 0],  ## under-sample ("majority")
]

# %%
## conduct smogn
df_smogn = smogn.smoter(
    
    ## main arguments
    data = df,           ## pandas dataframe
    y = 'Deceased',          ## string ('header name')
    k = 2,                    ## positive integer (k < n)
    pert = 0.04,              ## real number (0 < R < 1)
    samp_method = 'balance',  ## string ('balance' or 'extreme')
    drop_na_col = True,       ## boolean (True or False)
    drop_na_row = True,       ## boolean (True or False)
    replace = False,          ## boolean (True or False)

    ## phi relevance arguments
    rel_thres = 0.50,         ## real number (0 < R < 1)
    rel_method = 'manual',    ## string ('auto' or 'manual')
    # rel_xtrm_type = 'both', ## unused (rel_method = 'manual')
    # rel_coef = 1.50,        ## unused (rel_method = 'manual')
    rel_ctrl_pts_rg = rg_mtrx ## 2d array (format: [x, y])
)
# Out:
# ...
# r_index: 100%|##########| 214/214 [00:01<00:00, 190.67it/s]

# %%
df.shape
# Out:
# (35563, 90)

# %%
df_smogn.shape
# Out:
# (34587, 90)

# %%
## box plot stats - original data 
smogn.box_plot_stats(df['Deceased'])['stats']
# Out:
# array([0., 0., 0., 0., 0.])

# %%
## box plot stats - modified data
smogn.box_plot_stats(df_smogn['Deceased'])['stats']
# Out:
# array([0.        , 0.        , 1.17157288, 1.5       , 3.74165739])

# %%
#df_smogn.to_excel(r'C:\Users\Chris\OneDrive\Escritorio\KU Leuven\Master Thesis\Oversampled_Dataset.xlsx', index = False)

df_smogn.to_csv(r'C:\Users\Chris\OneDrive\Escritorio\Oversampled_dataset2.csv')
